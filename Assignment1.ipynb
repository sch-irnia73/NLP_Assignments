# %% [markdown]
# # [NLP] Assignment 1: Tokenization
#
# In this assignment, you need to tokenize the text of the Twitter(X) users posts(tweets). The assignment consists of two tasks. When you finish all the tasks, create a GitHub repository for this assignment (you can use this repo later for the other assignments) and submit this notebook in the repository. Leave `requirements.txt` file if your code requires additional installations. Submit the link to the repository in Moodle.
#
# The [data](https://drive.google.com/file/d/15x_wPAflvYQ2Xh38iNQGrqUIWLj5l5Nw/view?usp=share_link) contains 5 files whereby each contains 44 tweets. Each tweet is separated by a newline.

# %% [markdown]
# ## Task 1. Tokenize some tweets manually (20 points)
#
# As a first task you need to tokenize first 15 tweets from `file2` by hand. This will allow you to understand the problem from a linguistic point of view. The guidelines for tweet tokenization are as follows:
#
# - Each smiley is a separate token
# - Each hashtag is an individual token. Each user reference is an individual token
# - If a word has spaces between them then it is converted to a single token
# - All punctuations are individual tokens. This includes double-quotes and single quotes also
# - A URL is a single token
#
# Example of output
#
#     Input tweet
#     @xfranman Old age has made N A T O!
#
#     Tokenized tweet (separated by comma)
#     @xfranman , Old , age , has , made , NATO , !

# %% [markdown]
#     1. Input tweet
#     ...
#     1. Tokenized tweet
#     ...
#
#     2. Input tweet
#     ...
#     2. Tokenized tweet
#     ...

# %% [markdown]
#     1. Input tweet:
#     Camping in Maine for the weekend. Hey Dad, Mama Loves YOU: http://www.mamapalooza.com
#     1. Tokenized tweet (separated by comma):
#     Camping, in, Maine, for, the, weekend, ., Hey, Dad, ,, Mama, Loves, YOU, :, http://www.mamapalooza.com
#
#     2. Input tweet:
#     Its american tradition bitch
#     2. Tokenized tweet (separated by comma):
#     Its, american, tradition, bitch
#
#     3. Input tweet:
#     @ThroughTheVoid They love it! The only pleasure they get in life. I actually do that. I'm sure I hear a tiny squeak... Then louder ones
#     3. Tokenized tweet (separated by comma):
#     @ThroughTheVoid, They, love, it, !, The, only, pleasure, they, get, in, life, ., I, actually, do, that, ., I, ', m, sure, I, hear, a, tiny, squeak, ..., Then, louder, ones
#
#     4. Input tweet:
#     " RT @latti: @AbsoHilare stop tweeting in church! Lol <--- ""I tweet because I'm happy, I tweet because I'm free"" LOL!"
#     4. Tokenized tweet (separated by comma):
#     ", RT, @latti, :, @AbsoHilare, stop, tweeting, in, church, !, Lol, <---, ", ", I, tweet, because, I,', m, happy, ,, I, tweet, because, I, ', m, free, ", ", LOL, !, "
#
#     5. Input tweet:
#     Samsung Mini S2 portable HDD graced with colors that perfectly match your tacky beach gear: Sammy's done it aga.. http://tinyurl.com/lb5p6m
#     5. Tokenized tweet (separated by comma):
#     Samsung, Mini, S2, portable, HDD, graced, with, colors, that, perfectly, match, your, tacky, beach, gear, :, Sammy, ', s, done, it, aga, ., ., http://tinyurl.com/lb5p6m
#
#     6. Input tweet:
#     @dialloc congrats on finding your way over. it may be slow going at first. hang in there. it's kinda cool when u get up to speed.
#     6. Tokenized tweet (separated by comma):
#     @dialloc, congrats, on, finding, your, way, over, ., it, may, be, slow, going, at, first, ., hang, in, there, ., it, ', s, kinda, cool, when, u, get, up, to, speed, .
#
#     7. Input tweet:
#     iPhone activation delays continue, Apple offers $30 http://twt.gs/l3Ki
#     7. Tokenized tweet (separated by comma):
#     iPhone, activation, delays, continue, ,, Apple, offers, $, 30, http://twt.gs/l3Ki
#
#     8. Input tweet:
#     RT @GoogleAtWork Gmail maximum attachment size now 25MB http://bit.ly/62mjw Nice!!!
#     8. Tokenized tweet (separated by comma):
#     RT, @GoogleAtWork, Gmail, maximum, attachment, size, now, 25MB, http://bit.ly/62mjw, Nice, !, !, !
#
#     9. Input tweet:
#     RT @acfou The Ads Won Awards for Crispin; But Did Nothing for Client BurgerKing's Sales/Marketshare - Big Surprise - http://ping.fm/vw8TI
#     9. Tokenized tweet (separated by comma):
#     RT, @acfou, The, Ads, Won, Awards, for, Crispin, ;, But, Did, Nothing, for, Client, BurgerKing, ', s, Sales, /, Marketshare, -, Big, Surprise, -, http://ping.fm/vw8TI
#
#     10. Input tweet:
#     Hey doll! Great I missed True Blood yday boo lol Rt @FrankBanuat78 @jhillstephens Hello Sunshine how are u today? :-)
#     10. Tokenized tweet (separated by comma):
#     Hey, doll, !, Great, I, missed, True, Blood, yday, boo, lol, Rt, @FrankBanuat78, @jhillstephens, Hello, Sunshine, how, are, u, today, ?, :-)
#
#     11. Input tweet:
#     Australian artist Pogo made these free songs primarily from sampled audio from Alice In Wonderland. http://www.last.fm/music/Pogo/Wonderland
#     11. Tokenized tweet (separated by comma):
#     Australian, artist, Pogo, made, these, free, songs, primarily, from, sampled, audio, from, Alice, In, Wonderland, ., http://www.last.fm/music/Pogo/Wonderland
#
#     12. Input tweet:
#     @mppritchard they wanted to sell all the preorders & then sell all of the ones they had in stock to those that just walked in. Can't do both
#     12. Tokenized tweet (separated by comma):
#     @mppritchard, they, wanted, to, sell, all, the, preorders, &, then, sell, all, of, the, ones, they, had, in, stock, to, those, that, just, walked, in, ., Can, ', t, do, both
#
#     13. Input tweet:
#     Incoming: Frightened Rabbit, Sept. 22 (Tucson): If Fat Cat Records is going to send three great bands from Scot.. http://tinyurl.com/nz6xcv
#     13. Tokenized tweet (separated by comma):
#     Incoming, :, Frightened, Rabbit, ,, Sept, ., 22, (, Tucson, ), :, If, Fat, Cat, Records, is, going, to, send, three, great, bands, from, Scot, ., ., http://tinyurl.com/nz6xcv
#
#     14. Input tweet:
#     Hey @ginoandfran please greet philip! (GinoandFran live > http://ustre.am/2YyQ)
#     14. Tokenized tweet (separated by comma):
#     Hey, @ginoandfran, please, greet, philip, !, (, GinoandFran, live, >, http://ustre.am/2YyQ, )
#
#     15. Input tweet:
#     Ik weet niet wie er achter de T-Mobile iPhone Twitter zit maar ik vind het niet echt 'corporate' taalgebruik... Best vreemd eigenlijk
#     15. Tokenized tweet (separated by comma):
#     Ik, weet, niet, wie, er, achter, de, T, -, Mobile, iPhone, Twitter, zit, maar, ik, vind, het, niet, echt, ', corporate, ', taalgebruik, ..., Best, vreemd, eigenlijk

# %% [markdown]
# ## Task 2. Implement [Byte-Pair Encoding(BPE)](https://arxiv.org/pdf/1508.07909.pdf) Tokenizer (80 points)
#
# ### Task 2.1. Implementation (60 points)
#
# Implement the tokenizer as the BPETokenizer class:
# * Implement `train` method that learns merges and builds the vocabulary of the specified `vocab_size` (25 points).
# * Implement `tokenize` method that should tokenize the text according to the learnt merges (25 points).
#
# Your code should have docstrings and comments (10 points).

# %%
import re
from collections import defaultdict, Counter
from typing import List

class BPETokenizer:

    def __init__(self, vocab_size: int) -> None:
        self.vocab_size = vocab_size
        self.vocab = None
        self.merges = []
    
    def get_stats(self, vocab: dict) -> dict:
        #Compute frequency statistics for character pairs in the vocabulary.
        pairs = defaultdict(int)
        for word, freq in vocab.items():
            symbols = word.split()
            for i in range(len(symbols) -  1):
                pairs[symbols[i], symbols[i +  1]] += freq
        return pairs
    
    def merge_vocab(self, pair: tuple, vocab: dict) -> dict:
        #Merge the most common pair of consecutive characters in the vocabulary.
        v_out = {}
        bigram = re.escape(' '.join(pair))
        p = re.compile(r'(?<!\S)' + bigram + r'(?!\S)')
        for word in vocab:
            w_out = p.sub(''.join(pair), word)
            v_out[w_out] = vocab[word]
        return v_out
    
    def get_vocab(self, corpus: List[str]) -> dict:
        #Create a vocabulary from the given corpus.
        vocab = defaultdict(int)
        for line in corpus:
            for word in line.split():
                vocab[' '.join(list(word)) + ' </w>'] +=  1
        return vocab

    def train(self, corpus: List[str]) -> None:
        #Train the tokenizer with the given corpus.
        vocab = self.get_vocab(corpus)
        for _ in range(self.vocab_size - len(vocab)):
            pairs = self.get_stats(vocab)
            best = max(pairs, key=pairs.get)
            vocab = self.merge_vocab(best, vocab)
            self.merges.append(best)
        self.vocab = vocab

    def tokenize(self, text: str) -> List[str]:
        #Tokenize the given text using the trained vocabulary and merges.
        text = text.replace(' ', ' ')
        tokens = []
        for word in text.split():
            word_tokens = [word[:2]]
            for pair in self.merges:
                while True:
                    bigram = ' '.join(pair)
                    word_tokens = [wt + ' ' + bigram[wt.endswith(pair[0]):]
                                   for wt in word_tokens if word.find(bigram) != -1]
                    if not word_tokens:
                        break
            tokens.extend(word_tokens)
        return tokens

# %% [markdown]
# ### Task 2.2. Analysis on Tweets Dataset (10 points)
#
# Train the BPE tokenizer on the tweets dataset. Try to tokenize the tweets with the tokenizer of different `vocab_size`. For example, train the BPE tokenizer with `vocab_size` of [base_vocab_size, 250, 500, 750, 1000]. Plot the dependency of the average length of the tokenized tweet by `vocab_size` to analyze how `vocab_size` affects the length of the tokenized tweet on average. Tell what `vocab_size` is preferrable and why.

# %%
# Your code here
import matplotlib.pyplot as plt
from collections import Counter
import numpy as np

tweets = []
with open('Assignment1_data/file1', 'r') as file:
    content = file.read()
tweets = np.concatenate ((tweets, content.split('\n')))
# with open('Assignment1_data/file2', 'r') as file:
#     content = file.read()
# tweets = np.concatenate ((tweets, content.split('\n')))
# with open('Assignment1_data/file3', 'r') as file:
#     content = file.read()
# tweets = np.concatenate ((tweets, content.split('\n')))
# with open('Assignment1_data/file4', 'r') as file:
#     content = file.read()
# tweets = np.concatenate ((tweets, content.split('\n')))
# with open('Assignment1_data/file5', 'r') as file:
#     content = file.read()
# tweets = np.concatenate ((tweets, content.split('\n')))

# List of vocanulary sizes for the experiment
vocab_sizes = [1000,  750,  500,  250,  100]

# Dictionary for storing average lengths of tokenized tweets
avg_lengths = {}

for vocab_size in vocab_sizes:
    tokenizer = BPETokenizer(vocab_size)
    tokenizer.train(tweets)
    
    tokenized_tweets = [tokenizer.tokenize(tweet) for tweet in tweets]
    print(tokenized_tweets)
    lengths = [len(tokens) for tokens in tokenized_tweets]
    avg_length = sum(lengths) / len(lengths)
    
    avg_lengths[vocab_size] = avg_length

# Построение графика
plt.figure(figsize=(10,  5))
plt.plot(list(avg_lengths.keys()), list(avg_lengths.values()))
plt.xlabel('Vocab Size')
plt.ylabel('Average Length of Tokenized Tweet')
plt.title('Dependency of Average Length of Tokenized Tweet on Vocab Size')
plt.show()

# Интерпретация результатов
# Размер словаря, который минимизирует среднюю длину токенизированных твитов,
# будет считаться предпочтительным.
preferred_vocab_size = min(avg_lengths, key=avg_lengths.get)
print(f"Preferred vocab size: {preferred_vocab_size}")
# Out:
# [('e', '</w>'), ('s', '</w>'), ('i', 'n'), ('t', 'h'), ('t', '</w>'), ('e', 'r'), ('o', 'u'), ('d', '</w>'), ('a', 'n'), ('.', '</w>'), ('l', 'l'), ('y', '</w>'), ('a', 'r'), ('in', 'g'), ('o', 'r'), ('T', '</w>'), ('o', 'n'), ('h', 'a'), ('o', '</w>'), ('e', 'n'), ('s', 't'), ('t', 't'), ('ing', '</w>'), ('er', '</w>'), ('m', 'a'), ('a', 'c'), ('y', 'ou'), ('i', 't'), ('l', 'e'), (',', '</w>'), ('th', 'e</w>'), ('e', 'm'), ('u', 's'), ('#', 'S'), ('#S', 'em'), ('#Sem', 'S'), ('#SemS', 'T</w>'), ('a', '</w>'), ('r', 'e'), ('l', 'i'), ('h', 'tt'), ('htt', 'p'), ('http', ':'), ('http:', '/'), ('http:/', '/'), ('i', 'c'), ('l', 'e</w>'), (':', '</w>'), ('v', 'e</w>'), ('R', 'T</w>'), ('o', 'w'), ('you', '</w>'), ('t', 'o</w>'), ('ll', '</w>'), ('n', 'e'), ('a', 't'), ('o', 'f'), ('ar', 'e</w>'), ('o', 'm'), ('w', 'i'), ('!', '</w>'), ('r', 'i'), ('e', 's'), ('o', 'o'), ('f', 'or'), ('on', '</w>'), ('e', 'l'), ('n', 'o'), ('-', '</w>'), ('t', 'u'), ('e', 'd'), ('a', 'm'), ('i', 's</w>'), ('ow', '</w>'), ('a', 'g'), ('E', 'E'), ('"', '</w>'), ('.', '.'), ('c', 'h'), ('o', 's'), ('p', 'e'), ('an', '</w>'), ('in', '</w>'), ('o', 'd'), ('?', '</w>'), ('a', 's'), ('l', 'd</w>'), ('th', 'e'), ('g', 'h'), ('i', 'r'), ('of', '</w>'), ('s', 'h'), ('c', 'om'), ('t', 'e'), ('s', 'e'), ('an', 'd</w>'), ('i', 'ma'), ('o', 'p'), ('p', 'u'), ('w', 'or'), ('e', 'v'), ('i', 'd'), ('t', 'er'), ('a', 't</w>'), ('l', 'y'), ('I', '</w>'), ('l', '</w>'), ('.', 'com'), ('a', 'b'), ('th', '</w>'), ("'", 's</w>'), ('w', 'h'), ('r', 'ac'), ('i', '</w>'), ('g', 'e'), ('c', 'k'), ('http://', 'b'), ('http://b', 'it'), ('http://bit', '.'), ('http://bit.', 'ly'), ('http://bit.ly', '/'), ('b', 'e'), ('for', '</w>'), ('i', 'm'), ('e', 'd</w>'), ('us', 't</w>'), ('a', 'll'), ('l', 'd'), ('t', 'r'), ('r', '</w>'), ('j', 'e'), ('C', 'h'), ('w', 'a'), ('"', '"'), ('th', 'ing</w>'), ('..', '.</w>'), ('2', '0'), ('or', 'e</w>'), ('u', 'l'), ('e', 's</w>'), ('ha', 've</w>'), ('e', 'f'), ('b', 'u'), ('no', 't</w>'), ('a', 's</w>'), ('i', 's'), ('p', '</w>'), ('ou', 't</w>'), ('e', 'll'), ('n', '</w>'), ('b', 'i'), (')', '</w>'), ('i', 'on</w>'), ('h', 'e</w>'), ('t', 'a'), ('.com', '/'), ('el', '</w>'), ('i', 'an'), ('r', 'e</w>'), ('w', 'w'), ('EE', 'EE'), ('en', '</w>'), ('wi', 'th</w>'), ('you', 'r</w>'), ('A', 'I'), ('#', 'g'), ('w', 'e</w>'), ('J', 'es'), ('.', '.</w>'), ('ou', 'ld</w>'), ('p', 'le'), ('the', 'y</w>'), ('%', '</w>'), ('ou', 's</w>'), ('ge', 't</w>'), ('f', '</w>'), ('ch', 'e'), ('t', '.</w>'), ('f', 'o'), ('h', 'e'), ('k', 'e</w>'), ('be', 'ing</w>'), ('c', 'on'), ('I', "'"), ('v', 'er'), ('ed', '.</w>'), ('t', 'wi'), ('am', '</w>'), ('g', 'r'), ('m', 'an</w>'), ('c', 'e</w>'), ('a', 'll</w>'), ('f', 'e'), ('w', '</w>'), ('J', 'ust</w>'), ('o', 'st'), ('en', 't</w>'), ('th', 'r'), ('ou', 'gh'), ('th', 'er'), ('an', 'y</w>'), ('en', 't'), ('f', 'l'), ('ou', 's'), ('t', 'ic'), ('8', '4'), ('in', 's'), ('ir', 'd'), ('R', 'T'), ('wor', 'ld'), ('ar', '</w>'), ('c', 'ha'), ('h', 'o'), ('f', 'i'), ('b', 'le</w>'), ('ne', 'v'), ('nev', 'er</w>'), ('w', 'e'), ('k', '</w>'), ('c', 'a'), ('l', 'o'), ('lo', 've</w>'), ('th', 'er</w>'), ('on', 'g'), ('#', 'd'), ('g', 'o</w>'), ('e', ',</w>'), ('C', '</w>'), ('ev', 'er</w>'), ('AI', 'E'), ('AIE', 'S'), ('AIES', 'E'), ('L', 'ima'), ('wi', 'll</w>'), ('c', 'rac'), ('b', 'er'), ('ri', 'st'), ('je', 'je'), ('or', '</w>'), ('G', 'od'), ('o', 'd</w>'), ('ha', 't</w>'), ('Jes', 'us'), ('pe', 'op'), ('peop', 'le</w>'), ('it', 'a'), ('ou', 'r'), ('op', '</w>'), ('pu', 'tt'), ('putt', 'ing</w>'), ('g', 'at'), ('gat', 'e'), ('"', '"</w>'), ('y', 'thing</w>'), ('w', 'r'), ('it', 'e'), ('20', '%</w>'), ('M', 'ore</w>'), ('0', '</w>'), ('en', 'd'), ('i', 'gh'), ('O', 'N'), ('che', 'ck'), ('ou', 't.</w>'), ('5', '</w>'), ('p', 'a'), ('sh', 'o'), ('y', '.</w>'), ('L', 'i'), ('b', 'ar'), ('a', 'y</w>'), ('r', 'u'), ('ing', ',</w>'), ('bu', 't</w>'), ('is', 'c'), ('T', 'e'), ('C', 'ar'), ('li', 's'), ('h', 'el'), ('h', 'im'), ('hi ...
# [[], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], []]
# [('e', '</w>'), ('s', '</w>'), ('i', 'n'), ('t', 'h'), ('t', '</w>'), ('e', 'r'), ('o', 'u'), ('d', '</w>'), ('a', 'n'), ('.', '</w>'), ('l', 'l'), ('y', '</w>'), ('a', 'r'), ('in', 'g'), ('o', 'r'), ('T', '</w>'), ('o', 'n'), ('h', 'a'), ('o', '</w>'), ('e', 'n'), ('s', 't'), ('t', 't'), ('ing', '</w>'), ('er', '</w>'), ('m', 'a'), ('a', 'c'), ('y', 'ou'), ('i', 't'), ('l', 'e'), (',', '</w>'), ('th', 'e</w>'), ('e', 'm'), ('u', 's'), ('#', 'S'), ('#S', 'em'), ('#Sem', 'S'), ('#SemS', 'T</w>'), ('a', '</w>'), ('r', 'e'), ('l', 'i'), ('h', 'tt'), ('htt', 'p'), ('http', ':'), ('http:', '/'), ('http:/', '/'), ('i', 'c'), ('l', 'e</w>'), (':', '</w>'), ('v', 'e</w>'), ('R', 'T</w>'), ('o', 'w'), ('you', '</w>'), ('t', 'o</w>'), ('ll', '</w>'), ('n', 'e'), ('a', 't'), ('o', 'f'), ('ar', 'e</w>'), ('o', 'm'), ('w', 'i'), ('!', '</w>'), ('r', 'i'), ('e', 's'), ('o', 'o'), ('f', 'or'), ('on', '</w>'), ('e', 'l'), ('n', 'o'), ('-', '</w>'), ('t', 'u'), ('e', 'd'), ('a', 'm'), ('i', 's</w>'), ('ow', '</w>'), ('a', 'g'), ('E', 'E'), ('"', '</w>'), ('.', '.'), ('c', 'h'), ('o', 's'), ('p', 'e'), ('an', '</w>'), ('in', '</w>'), ('o', 'd'), ('?', '</w>'), ('a', 's'), ('l', 'd</w>'), ('th', 'e'), ('g', 'h'), ('i', 'r'), ('of', '</w>'), ('s', 'h'), ('c', 'om'), ('t', 'e'), ('s', 'e'), ('an', 'd</w>'), ('i', 'ma'), ('o', 'p'), ('p', 'u'), ('w', 'or'), ('e', 'v'), ('i', 'd'), ('t', 'er'), ('a', 't</w>'), ('l', 'y'), ('I', '</w>'), ('l', '</w>'), ('.', 'com'), ('a', 'b'), ('th', '</w>'), ("'", 's</w>'), ('w', 'h'), ('r', 'ac'), ('i', '</w>'), ('g', 'e'), ('c', 'k'), ('http://', 'b'), ('http://b', 'it'), ('http://bit', '.'), ('http://bit.', 'ly'), ('http://bit.ly', '/'), ('b', 'e'), ('for', '</w>'), ('i', 'm'), ('e', 'd</w>'), ('us', 't</w>'), ('a', 'll'), ('l', 'd'), ('t', 'r'), ('r', '</w>'), ('j', 'e'), ('C', 'h'), ('w', 'a'), ('"', '"'), ('th', 'ing</w>'), ('..', '.</w>'), ('2', '0'), ('or', 'e</w>'), ('u', 'l'), ('e', 's</w>'), ('ha', 've</w>'), ('e', 'f'), ('b', 'u'), ('no', 't</w>'), ('a', 's</w>'), ('i', 's'), ('p', '</w>'), ('ou', 't</w>'), ('e', 'll'), ('n', '</w>'), ('b', 'i'), (')', '</w>'), ('i', 'on</w>'), ('h', 'e</w>'), ('t', 'a'), ('.com', '/'), ('el', '</w>'), ('i', 'an'), ('r', 'e</w>'), ('w', 'w'), ('EE', 'EE'), ('en', '</w>'), ('wi', 'th</w>'), ('you', 'r</w>'), ('A', 'I'), ('#', 'g'), ('w', 'e</w>'), ('J', 'es'), ('.', '.</w>'), ('ou', 'ld</w>'), ('p', 'le'), ('the', 'y</w>'), ('%', '</w>'), ('ou', 's</w>'), ('ge', 't</w>'), ('f', '</w>'), ('ch', 'e'), ('t', '.</w>'), ('f', 'o'), ('h', 'e'), ('k', 'e</w>'), ('be', 'ing</w>'), ('c', 'on'), ('I', "'"), ('v', 'er'), ('ed', '.</w>'), ('t', 'wi'), ('am', '</w>'), ('g', 'r'), ('m', 'an</w>'), ('c', 'e</w>'), ('a', 'll</w>'), ('f', 'e'), ('w', '</w>'), ('J', 'ust</w>'), ('o', 'st'), ('en', 't</w>'), ('th', 'r'), ('ou', 'gh'), ('th', 'er'), ('an', 'y</w>'), ('en', 't'), ('f', 'l'), ('ou', 's'), ('t', 'ic'), ('8', '4'), ('in', 's'), ('ir', 'd'), ('R', 'T'), ('wor', 'ld'), ('ar', '</w>'), ('c', 'ha'), ('h', 'o'), ('f', 'i'), ('b', 'le</w>'), ('ne', 'v'), ('nev', 'er</w>'), ('w', 'e'), ('k', '</w>'), ('c', 'a'), ('l', 'o'), ('lo', 've</w>'), ('th', 'er</w>'), ('on', 'g'), ('#', 'd'), ('g', 'o</w>'), ('e', ',</w>'), ('C', '</w>'), ('ev', 'er</w>'), ('AI', 'E'), ('AIE', 'S'), ('AIES', 'E'), ('L', 'ima'), ('wi', 'll</w>'), ('c', 'rac'), ('b', 'er'), ('ri', 'st'), ('je', 'je'), ('or', '</w>'), ('G', 'od'), ('o', 'd</w>'), ('ha', 't</w>'), ('Jes', 'us'), ('pe', 'op'), ('peop', 'le</w>'), ('it', 'a'), ('ou', 'r'), ('op', '</w>'), ('pu', 'tt'), ('putt', 'ing</w>'), ('g', 'at'), ('gat', 'e'), ('"', '"</w>'), ('y', 'thing</w>'), ('w', 'r'), ('it', 'e'), ('20', '%</w>'), ('M', 'ore</w>'), ('0', '</w>'), ('en', 'd'), ('i', 'gh')]
# [[], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], []]
# [('e', '</w>'), ('s', '</w>'), ('i', 'n'), ('t', 'h'), ('t', '</w>'), ('e', 'r'), ('o', 'u'), ('d', '</w>'), ('a', 'n'), ('.', '</w>'), ('l', 'l')]
# [[], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], []]
# []
# [['@a', 'wa'], ['"', 'Co', 'jo', 'pl', 'st', 'pu', 'th', 'wo', '""', 'af', 'ev', 'th', 'wr', 'ga'], ['20', 'Mo', 'Ri', 'Sa', '@2', 'en', 'to', '-', 'ge', '20', 'of', 'by', 'en', "'R", 'at', 'ch', 'Mo', 'in', 'ht'], ['@S', 'I', 'ha', 'a', 'pa', 'of', 'th', 'sh', 'Th', 'ar', 'co', 'Li', 'be', 'ba', 'Ok', 'fo', 'ru', 'bu', 'no', 'on', 'co', 'as', "I'", 'di'], ['RT', '@t', 'Te', 'Ca', 'is', 'a', 'Tr', 'To', 'he', 'hi', 'ou', 'RT', 'Fo', '@p', 'se', 'a', 'gr', 'ma', 'n', 'a', 'bi', 'da', 'Ho', 'Bl'], ['@k', 'yo', 'mi', 'ha', 'to', 're', '-', 'th', 'ha', 'to', 'me', 'a', 'fe', 'mo', 'ag', 'no', 'I', 'us', 'Na', 'on', 'my', 'Ma'], ['Ju', 'Po', 'Re', 'Dr', '-', 'Pa', 'XX', '(h'], ['"', '""', 'Mc', '..', 'we', 'th', 'al', 'hi', 'ed', 'th', 'an', 'no', 'th', 'he', 'ha', 'an', 'mu', 'ta', 'ht'], ['@a', 'Ye', 'pr', 'mu', 'ho', 'i', 'fe', 'ab', 'it'], ['@f', 'No', 're', 'no', 'Ar', 'yo', 'ki'], ['@t', 'Ho'], ['"', 'Ob', 'th', 'Mu', 'be', '""', 'l"'], ['RT', '@B', '81', 'of', 'tw', 'us', 'ar', 'UN', '30', '+', 'mo', 'v.', 'in', 'st', 'he', 'ht'], ['@B', 'Gr', 'lo', 'hu', 'RT', 'wo', 'mo', 'sp', 'hu', 'Ma', 'Sp', 'on', 'a', 'fe', 'ht'], ['at', 'ch', 'wh', 'RT', '@v', 'Jo', 'Br', 'at', 'Ro', 'Ce', 'fo', 'th', 'To', 'Sh', 'to', 'mo'], ['aw', 'fu', 'it', 'tu', 'ou', 'yo', 'ca', 'de', 'th', 'ch', 'gl', 'ho', 'tu'], ['RT', '@u', 'My', 'li', 'ha', 'be', 'fi', 'wi', 'te', 'mi', 'mo', 'of', 'wh', 'ne', 'ha', '~', 'So', 'tr'], ['RT', '@w', 'Th', 'Wo', 'Sm', 'Wh', 'Sh', '-', 'ht'], ['He', '@a', 'ch', 'an', 'ca', 'wi', 'tw', "e'", 'lo', 'yo', 'do', 'yo', 'lo', 'us', '(A', 'li', '>', 'ht'], ['*s'], ['Li', 'fo', 'tr', '-', 'an', 'pr', 'tr', 'wi', 'Tf', 'st', '..', 'ht'], ['@T', "I'", 'pu', 'yo', 'so', 'on', 'th', 'po', 'so', 'fo', 'ca', 'ch', 'yo', 'ou', "I'", 'gi', 'th', 'my', 'si', 'as', 'we'], ['RT', '@m', 'RT', '@T', 'An', 'ra', 'th', '#t', '#h', '#d'], ['If', 'my', 'do', 'sh', 'go', 'bl', 'in', 'ol', 'ag', 'wo', 'it', 'be', 'ki', 'to', 'ha', 'hi', 'pu', 'to', 'sl', 'ht'], ['Ju', 'pu', '1', 'MP', 'Gr', 'ht', '#1'], ['@M', 'Di', 'th', 'Wh', 'So', 'ev', 'ac', 'we', 'th', 'un', 'ar', 'ar', 'th', 'ju', 'th'], ['RT', '@A', 'AI', 'Li', '-', 'AI', 'Sa', 'Ma', 'EB', 'ga', 'at', 'Ju', '(L', 'Li', 'pl', 'ht', 'ht'], ['If', 'an', 'in', 'gi', 'ge', 'sh', 'ha', 'ac', 'th', 'wo', 'do', 'sh', 'ma', 'a', 'so', 'Ye', 'th', 'wh', 'wo', 'he', 'he', '&', 'wi', '#i', '#n', 'RT'], ['RT', '@c', 'RT', '@j', '@c', 'je', 'gr', 'po', 'el', 'RT', 'Va', 'pu', 'a', 'CD', '(C', 'HP', 'QT', 'je', '#a'], ['Bl', 'ar', 'th', 'pe', 'fo', 'th', 'sh', 'be', 'ca', 'ch', 'of', 'Go', 'Ma', '5:', '#s', '#p', '#S'], ['Bu', 'I', 'am', 'li', 'a', 'gr', 'ol', 'tr', 'in', 'th', 'ho', 'of', 'Go', 'I', 'wi', 'tr', 'in', 'th', 'me', 'of', 'Go', 'fo', 'an', 'ev', '-P', '52', '#S'], ['@m', 'It', 've', 'co', 'bu', 'it', 'no', 'ev', 'fo', 'an', '#g', 'Is', 'th', 'wh', 'yo', 'im', '#S'], ['In', '#C', 'we', 'ar', 'ri', 'an', 'in', 'pr', 'we', 'ar', 'be', 'co', 'to', 'Hi', 'im', 'Ch', 'In', '#Q', '#F', '#T', '#S'], ['Gr', 'is', 'He', 'wh', 'is', 'in', 'yo', 'th', 'he', 'wh', 'is', 'in', 'th', 'wo', '-', '1J', '4:', '#g', '#b', '#S'], ['As', 'yo', 'fo', 'Me', 'I', 'le', 'yo', 'al', 'pa', 'of', 'ne', 'wa', 'yo', 'ha', 'ne', 'im', '-', '@J', '#S'], ['Fi', 'yo', 'ch', 'wi', 'ho', 'fa', 'fo', 'th', 'ma', 'Ch', 'Je', 'He', 'is', 'wh', 'we', 'ne', '#w', '#o', '#m', '#o', '#S'], ['It', 'wi', 'ne', 'ge', 'ol', 'to', 'he', 'wh', 'Ch', 'le', 'ot', 'to', 'ul', 'lo', '&', 'ho', '#d', '#s', '#g', '#J', '#S'], ['Re', 'pe', 'ar', 'pe', 'to', 'Ju', 'bi', 'mu', 'an', 'gu', 'pe', '#S'], ['Th', 'na', 'do', 'yo', 'ke', 'ha', 'ab', 'go', 'Go', 'no', 'te', 'u,', 'it', 'yo', 'in', 'tr', 'to', 'te', 'yo', 'yo', 'be', 'ar', 'bu', '#S'], ['Go', 'is', 'so', 'go', 'Al', 'th', 'pr', 'go', 'up', 'to', 'Hi', '#S'], ['@x', 'Ol', 'ag', 'ha', 'no', 'ma', 'yo', 'an', 'wi', 'or', 'mo', 'ma', 'Fo', 'sh', '#S'], ['@H', '@N', '@c', '@P', 'Bo', 'ar', 'ut', 'st', 'an', 'us', 'an', '#l', '#d', '#S'], ['Al', 'we', 'ne', 'is', 'to', 'go', 'ba', 'to', ...
# []
# [['@a', 'wa'], ['"', 'Co', 'jo', 'pl', 'st', 'pu', 'th', 'wo', '""', 'af', 'ev', 'th', 'wr', 'ga'], ['20', 'Mo', 'Ri', 'Sa', '@2', 'en', 'to', '-', 'ge', '20', 'of', 'by', 'en', "'R", 'at', 'ch', 'Mo', 'in', 'ht'], ['@S', 'I', 'ha', 'a', 'pa', 'of', 'th', 'sh', 'Th', 'ar', 'co', 'Li', 'be', 'ba', 'Ok', 'fo', 'ru', 'bu', 'no', 'on', 'co', 'as', "I'", 'di'], ['RT', '@t', 'Te', 'Ca', 'is', 'a', 'Tr', 'To', 'he', 'hi', 'ou', 'RT', 'Fo', '@p', 'se', 'a', 'gr', 'ma', 'n', 'a', 'bi', 'da', 'Ho', 'Bl'], ['@k', 'yo', 'mi', 'ha', 'to', 're', '-', 'th', 'ha', 'to', 'me', 'a', 'fe', 'mo', 'ag', 'no', 'I', 'us', 'Na', 'on', 'my', 'Ma'], ['Ju', 'Po', 'Re', 'Dr', '-', 'Pa', 'XX', '(h'], ['"', '""', 'Mc', '..', 'we', 'th', 'al', 'hi', 'ed', 'th', 'an', 'no', 'th', 'he', 'ha', 'an', 'mu', 'ta', 'ht'], ['@a', 'Ye', 'pr', 'mu', 'ho', 'i', 'fe', 'ab', 'it'], ['@f', 'No', 're', 'no', 'Ar', 'yo', 'ki'], ['@t', 'Ho'], ['"', 'Ob', 'th', 'Mu', 'be', '""', 'l"'], ['RT', '@B', '81', 'of', 'tw', 'us', 'ar', 'UN', '30', '+', 'mo', 'v.', 'in', 'st', 'he', 'ht'], ['@B', 'Gr', 'lo', 'hu', 'RT', 'wo', 'mo', 'sp', 'hu', 'Ma', 'Sp', 'on', 'a', 'fe', 'ht'], ['at', 'ch', 'wh', 'RT', '@v', 'Jo', 'Br', 'at', 'Ro', 'Ce', 'fo', 'th', 'To', 'Sh', 'to', 'mo'], ['aw', 'fu', 'it', 'tu', 'ou', 'yo', 'ca', 'de', 'th', 'ch', 'gl', 'ho', 'tu'], ['RT', '@u', 'My', 'li', 'ha', 'be', 'fi', 'wi', 'te', 'mi', 'mo', 'of', 'wh', 'ne', 'ha', '~', 'So', 'tr'], ['RT', '@w', 'Th', 'Wo', 'Sm', 'Wh', 'Sh', '-', 'ht'], ['He', '@a', 'ch', 'an', 'ca', 'wi', 'tw', "e'", 'lo', 'yo', 'do', 'yo', 'lo', 'us', '(A', 'li', '>', 'ht'], ['*s'], ['Li', 'fo', 'tr', '-', 'an', 'pr', 'tr', 'wi', 'Tf', 'st', '..', 'ht'], ['@T', "I'", 'pu', 'yo', 'so', 'on', 'th', 'po', 'so', 'fo', 'ca', 'ch', 'yo', 'ou', "I'", 'gi', 'th', 'my', 'si', 'as', 'we'], ['RT', '@m', 'RT', '@T', 'An', 'ra', 'th', '#t', '#h', '#d'], ['If', 'my', 'do', 'sh', 'go', 'bl', 'in', 'ol', 'ag', 'wo', 'it', 'be', 'ki', 'to', 'ha', 'hi', 'pu', 'to', 'sl', 'ht'], ['Ju', 'pu', '1', 'MP', 'Gr', 'ht', '#1'], ['@M', 'Di', 'th', 'Wh', 'So', 'ev', 'ac', 'we', 'th', 'un', 'ar', 'ar', 'th', 'ju', 'th'], ['RT', '@A', 'AI', 'Li', '-', 'AI', 'Sa', 'Ma', 'EB', 'ga', 'at', 'Ju', '(L', 'Li', 'pl', 'ht', 'ht'], ['If', 'an', 'in', 'gi', 'ge', 'sh', 'ha', 'ac', 'th', 'wo', 'do', 'sh', 'ma', 'a', 'so', 'Ye', 'th', 'wh', 'wo', 'he', 'he', '&', 'wi', '#i', '#n', 'RT'], ['RT', '@c', 'RT', '@j', '@c', 'je', 'gr', 'po', 'el', 'RT', 'Va', 'pu', 'a', 'CD', '(C', 'HP', 'QT', 'je', '#a'], ['Bl', 'ar', 'th', 'pe', 'fo', 'th', 'sh', 'be', 'ca', 'ch', 'of', 'Go', 'Ma', '5:', '#s', '#p', '#S'], ['Bu', 'I', 'am', 'li', 'a', 'gr', 'ol', 'tr', 'in', 'th', 'ho', 'of', 'Go', 'I', 'wi', 'tr', 'in', 'th', 'me', 'of', 'Go', 'fo', 'an', 'ev', '-P', '52', '#S'], ['@m', 'It', 've', 'co', 'bu', 'it', 'no', 'ev', 'fo', 'an', '#g', 'Is', 'th', 'wh', 'yo', 'im', '#S'], ['In', '#C', 'we', 'ar', 'ri', 'an', 'in', 'pr', 'we', 'ar', 'be', 'co', 'to', 'Hi', 'im', 'Ch', 'In', '#Q', '#F', '#T', '#S'], ['Gr', 'is', 'He', 'wh', 'is', 'in', 'yo', 'th', 'he', 'wh', 'is', 'in', 'th', 'wo', '-', '1J', '4:', '#g', '#b', '#S'], ['As', 'yo', 'fo', 'Me', 'I', 'le', 'yo', 'al', 'pa', 'of', 'ne', 'wa', 'yo', 'ha', 'ne', 'im', '-', '@J', '#S'], ['Fi', 'yo', 'ch', 'wi', 'ho', 'fa', 'fo', 'th', 'ma', 'Ch', 'Je', 'He', 'is', 'wh', 'we', 'ne', '#w', '#o', '#m', '#o', '#S'], ['It', 'wi', 'ne', 'ge', 'ol', 'to', 'he', 'wh', 'Ch', 'le', 'ot', 'to', 'ul', 'lo', '&', 'ho', '#d', '#s', '#g', '#J', '#S'], ['Re', 'pe', 'ar', 'pe', 'to', 'Ju', 'bi', 'mu', 'an', 'gu', 'pe', '#S'], ['Th', 'na', 'do', 'yo', 'ke', 'ha', 'ab', 'go', 'Go', 'no', 'te', 'u,', 'it', 'yo', 'in', 'tr', 'to', 'te', 'yo', 'yo', 'be', 'ar', 'bu', '#S'], ['Go', 'is', 'so', 'go', 'Al', 'th', 'pr', 'go', 'up', 'to', 'Hi', '#S'], ['@x', 'Ol', 'ag', 'ha', 'no', 'ma', 'yo', 'an', 'wi', 'or', 'mo', 'ma', 'Fo', 'sh', '#S'], ['@H', '@N', '@c', '@P', 'Bo', 'ar', 'ut', 'st', 'an', 'us', 'an', '#l', '#d', '#S'], ['Al', 'we', 'ne', 'is', 'to', 'go', 'ba', 'to', ...
# Preferred vocab size: 1000

# %% [markdown]
# ### Task 2.3. Analysis on Dataset of Different Language (10 points)
#
# Find a small dataset of texts in a language other than English. The dataset size should be not greater than several megabytes.
#
# Train the BPE tokenizer on the dataset that you found. Try to tokenize the sentences from this dataset with the tokenizer of different `vocab_size`. Plot the dependency of the average length of the tokenized sentence by `vocab_size` to analyze how `vocab_size` affects the length of the tokenized sentence on average.
#
# Tell how how the average length of the tokenized sentence differs from the average length of the tokenized tweet. Explain why.

# %%
# Your code here
